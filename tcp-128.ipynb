# %%
import pandas as pd

# %%
df = pd.read_csv('/Users/heiko/Development/drasyl/WormholeSendChildChannelInitializer-67402.csv')
df
# Out:
#        pid                            time     SND.UNA     SND.NXT  SND.WND  \
# 0    67402  Sat, 7 Jan 2023 15:55:49 +0100   807389637   807389637   156160
# 1    67402  Sat, 7 Jan 2023 15:55:49 +0100   807389709   807389709   156160
# 2    67402  Sat, 7 Jan 2023 15:55:49 +0100   807449867   807481251   156160
# 3    67402  Sat, 7 Jan 2023 15:55:49 +0100   807715715   807749607   156160
# 4    67402  Sat, 7 Jan 2023 15:55:49 +0100   808203555   808236159   156160
# ..     ...                             ...         ...         ...      ...
# 757  67402  Sat, 7 Jan 2023 15:57:04 +0100  1729927413  1729961271   156160
# 758  67402  Sat, 7 Jan 2023 15:57:04 +0100  1729927413  1729961271   156160
# 759  67402  Sat, 7 Jan 2023 15:57:05 +0100  1731414623  1731444753   156160
# 760  67402  Sat, 7 Jan 2023 15:57:05 +0100  1733291895  1733339547   156160
# 761  67402  Sat, 7 Jan 2023 15:57:05 +0100  1735152797  1735211769   156160
#
# ...

# %%
df['SND.UNA'].plot()
# Out:
# <AxesSubplot: >

# %%
df['SND.NXT'].plot()
# Out:
# <AxesSubplot: >

# %%
df['Unacknowledged Data'] = df['SND.NXT'] - df['SND.UNA']
df['Unacknowledged Data'].plot()
# Out:
# <AxesSubplot: >

# %%
df['SND.WND'].describe()
# Out:
# count       762.0
# mean     156160.0
# std           0.0
# min      156160.0
# 25%      156160.0
# 50%      156160.0
# 75%      156160.0
# max      156160.0
# Name: SND.WND, dtype: float64

# %%
df['SND.WL1'].plot()
# Out:
# <AxesSubplot: >

# %%
df['SND.WL2'].plot()
# Out:
# <AxesSubplot: >

# %%
df['RCV.NXT'].plot()
# Out:
# <AxesSubplot: >

# %%
df['RCV.WND'].plot()
# Out:
# <AxesSubplot: >
