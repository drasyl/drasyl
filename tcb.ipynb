# %%
import pandas as pd

df = pd.read_csv('./tcb.csv')
df['time'] = pd.to_datetime(df['time'], unit='ms')
df.set_index('time', inplace=True)
df
# Out:
#                           ssthresh    cwnd
# time
# 2023-12-26 20:39:02.323  6553500.0  3649.0
# 2023-12-26 20:39:02.479  6553500.0  3653.0
# 2023-12-26 20:39:02.655  6553500.0  3742.0
# 2023-12-26 20:39:02.656  6553500.0  4958.0
# 2023-12-26 20:39:02.722  6553500.0  4993.0
# ...                            ...     ...
# 2023-12-26 20:39:17.148   160128.0  1251.0
# 2023-12-26 20:39:18.149   160110.0  1251.0
# 2023-12-26 20:39:18.149   160110.0  1216.0
# 2023-12-26 20:39:18.171   160110.0  2432.0
# 2023-12-26 20:39:19.176        NaN     NaN
#
# [1157 rows x 2 columns]

# %%
plt.figure(figsize=(10, 6))
#plt.plot(df.index, df['ssthresh'], label='ssthresh')
plt.plot(df.index, df['cwnd'], label='cwnd')

# Titel und Beschriftungen hinzufügen
plt.title('Zeitlicher Verlauf von sshtresh und cwnd')
plt.xlabel('Zeit')
plt.ylabel('Werte')
plt.legend()

# Zeige den Plot an
plt.show()
