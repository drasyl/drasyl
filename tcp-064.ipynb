# %%
import pandas as pd

# %%
df = pd.read_csv('/Users/heiko/Development/drasyl/WormholeSendChildChannelInitializer-72981.csv')
df
# Out:
#        pid                            time     SND.UNA     SND.NXT  SND.WND  \
# 0    72981  Sat, 7 Jan 2023 17:34:17 +0100   736756949   736756949    78080
# 1    72981  Sat, 7 Jan 2023 17:34:17 +0100   736757021   736757021    78080
# 2    72981  Sat, 7 Jan 2023 17:34:17 +0100   736780205   736819721    78080
# 3    72981  Sat, 7 Jan 2023 17:34:17 +0100   737026631   737060489    78080
# 4    72981  Sat, 7 Jan 2023 17:34:17 +0100   737483087   737539517    78080
# ..     ...                             ...         ...         ...      ...
# 475  72981  Sat, 7 Jan 2023 17:35:04 +0100  1360117879  1360151771    78080
# 476  72981  Sat, 7 Jan 2023 17:35:04 +0100  1360117879  1360151771    78080
# 477  72981  Sat, 7 Jan 2023 17:35:05 +0100  1360117879  1360151771    78080
# 478  72981  Sat, 7 Jan 2023 17:35:05 +0100  1360664623  1360718579    78080
# 479  72981  Sat, 7 Jan 2023 17:35:05 +0100  1362757515  1362801473    78080
#
# ...

# %%
df['SND.UNA'].plot()
# Out:
# <AxesSubplot: >

# %%
df['SND.NXT'].plot()
# Out:
# <AxesSubplot: >

# %%
df['Unacknowledged Data'] = df['SND.NXT'] - df['SND.UNA']
df['Unacknowledged Data'].plot()
# Out:
# <AxesSubplot: >

# %%
df['SND.WND'].describe()
# Out:
# count      480.0
# mean     78080.0
# std          0.0
# min      78080.0
# 25%      78080.0
# 50%      78080.0
# 75%      78080.0
# max      78080.0
# Name: SND.WND, dtype: float64

# %%
df['SND.WL1'].plot()
# Out:
# <AxesSubplot: >

# %%
df['SND.WL2'].plot()
# Out:
# <AxesSubplot: >

# %%
df['RCV.NXT'].plot()
# Out:
# <AxesSubplot: >

# %%
df['RCV.WND'].plot()
# Out:
# <AxesSubplot: >

# %%
df['SND.BUF'].plot()
# Out:
# <AxesSubplot: >

# %%
df['OG.SEG.Q'].plot()
# Out:
# <AxesSubplot: >

# %%
df['RTNS.Q'].plot()
# Out:
# <AxesSubplot: >

# %%
df['RCV.BUF'].plot()
# Out:
# <AxesSubplot: >

# %%
df['CWND'].plot()
# Out:
# <AxesSubplot: >

# %%
df['SSTHRESH'].plot()
# Out:
# <AxesSubplot: >
