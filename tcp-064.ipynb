# %%
import pandas as pd

# %%
df = pd.read_csv('/Users/heiko/Development/drasyl/WormholeSendChildChannelInitializer-6195.csv')
df
# Out:
#       pid                            time     SND.UNA     SND.NXT  SND.WND  \
# 0    6195  Sun, 8 Jan 2023 01:12:36 +0100   976661702   976661703    78080
# 1    6195  Sun, 8 Jan 2023 01:12:36 +0100   976661702   976661703    78080
# 2    6195  Sun, 8 Jan 2023 01:12:36 +0100   976661703   976661703    78080
# 3    6195  Sun, 8 Jan 2023 01:12:37 +0100   976661703   976665370    78080
# 4    6195  Sun, 8 Jan 2023 01:12:37 +0100   976661703   976665370    78080
# ..    ...                             ...         ...         ...      ...
# 932  6195  Sun, 8 Jan 2023 01:14:09 +0100  1563211411  1563266315    78080
# 933  6195  Sun, 8 Jan 2023 01:14:10 +0100  1563928647  1563987211    78080
# 934  6195  Sun, 8 Jan 2023 01:14:10 +0100  1564511499  1564544267    78080
# 935  6195  Sun, 8 Jan 2023 01:14:10 +0100  1565226643  1565265163    78080
# 936  6195  Sun, 8 Jan 2023 01:14:10 +0100  1566000351  1566043403    78080
#
# ...

# %%
df['SND.UNA'].plot()
# Out:
# <AxesSubplot: >

# %%
df['SND.NXT'].plot()
# Out:
# <AxesSubplot: >

# %%
df['Unacknowledged Data'] = df['SND.NXT'] - df['SND.UNA']
df['Unacknowledged Data'].plot()
# Out:
# <AxesSubplot: >

# %%
df['SND.WND'].describe()
# Out:
# count      937.0
# mean     78080.0
# std          0.0
# min      78080.0
# 25%      78080.0
# 50%      78080.0
# 75%      78080.0
# max      78080.0
# Name: SND.WND, dtype: float64

# %%
df['SND.WL1'].plot()
# Out:
# <AxesSubplot: >

# %%
df['SND.WL2'].plot()
# Out:
# <AxesSubplot: >

# %%
df['RCV.NXT'].plot()
# Out:
# <AxesSubplot: >

# %%
df['RCV.WND'].plot()
# Out:
# <AxesSubplot: >

# %%
df['SND.BUF'].plot()
# Out:
# <AxesSubplot: >

# %%
df['OG.SEG.Q'].plot()
# Out:
# <AxesSubplot: >

# %%
df['RTNS.Q'].plot()
# Out:
# <AxesSubplot: >

# %%
df['RCV.BUF'].plot()
# Out:
# <AxesSubplot: >

# %%
df['CWND'].plot()
# Out:
# <AxesSubplot: >

# %%
df['SSTHRESH'].plot()
# Out:
# <AxesSubplot: >
