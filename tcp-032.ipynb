# %%
import pandas as pd

# %%
df = pd.read_csv('/Users/heiko/Development/drasyl/WormholeSendChildChannelInitializer-67684.csv')
df
# Out:
#         pid                            time     SND.UNA     SND.NXT  SND.WND  \
# 0     67684  Sat, 7 Jan 2023 15:59:05 +0100   881703130   881703130    39040
# 1     67684  Sat, 7 Jan 2023 15:59:05 +0100   881703202   881703202    39040
# 2     67684  Sat, 7 Jan 2023 15:59:06 +0100   881738280   881777320    39040
# 3     67684  Sat, 7 Jan 2023 15:59:06 +0100   881866188   881895064    39040
# 4     67684  Sat, 7 Jan 2023 15:59:06 +0100   882137218   882176258    39040
# ...     ...                             ...         ...         ...      ...
# 2563  67684  Sat, 7 Jan 2023 16:03:22 +0100  1805892888  1805925028    39040
# 2564  67684  Sat, 7 Jan 2023 16:03:22 +0100  1807027260  1807066306    39040
# 2565  67684  Sat, 7 Jan 2023 16:03:22 +0100  1808212822  1808244928    39040
# 2566  67684  Sat, 7 Jan 2023 16:03:22 +0100  1809397686  1809436228    39040
# 2567  67684  Sat, 7 Jan 2023 16:03:22 +0100  1810628748  1810658878    39040
#
# ...

# %%
df['SND.UNA'].plot()
# Out:
# <AxesSubplot: >

# %%
df['SND.NXT'].plot()
# Out:
# <AxesSubplot: >

# %%
df['Unacknowledged Data'] = df['SND.NXT'] - df['SND.UNA']
df['Unacknowledged Data'].plot()
# Out:
# <AxesSubplot: >

# %%
df['SND.WND'].describe()
# Out:
# count     2568.0
# mean     39040.0
# std          0.0
# min      39040.0
# 25%      39040.0
# 50%      39040.0
# 75%      39040.0
# max      39040.0
# Name: SND.WND, dtype: float64

# %%
df['SND.WL1'].plot()
# Out:
# <AxesSubplot: >

# %%
df['SND.WL2'].plot()
# Out:
# <AxesSubplot: >

# %%
df['RCV.NXT'].plot()
# Out:
# <AxesSubplot: >

# %%
df['RCV.WND'].plot()
# Out:
# <AxesSubplot: >
